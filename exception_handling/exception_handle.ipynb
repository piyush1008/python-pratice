# %% [markdown]
# ### Understanding exceptions
#
# Exception handling in python allows you to handle errors gracefully and take corrective actions without stoppping the execution of the progam. THis lesson will cover the basics of exceptions, including how to use try, except, else and finally blocks.
#
# ### What are exceptions?
#
# They are events that disrupt the normal flow of a program. They occur when an error is encountered during program execution. Common exception include:
# 1. ZerodivisonError: Dividing by zero
# 2. FileNotFoundError: file not found
# 3. ValueError: Invalid value.

# %%
## Exception , try , except block
try: 
    a==b
except:
    print("the variable needs to be intialised")
finally:
    print("this will be printed regardless")
# Out:
# the variable needs to be intialised
# this will be printed regardless

# %%
try: 
    a==b
except NameError as ex:
    print(ex)
finally:
    print("this will be printed regardless")
# Out:
# name 'a' is not defined
# this will be printed regardless

# %%
# result=1/0   #ZeroDivisionError division by zero

try:
    result=1/0
    a=b
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denomintor greater than 0")

except Exception as ex1:
    print(ex1)
# Out:
# division by zero
# Please enter the denomintor greater than 0

# %%
try:
    num=int(input("enter a number"))
    result=10/num
except ValueError:
    print("this is not valid number")
except Exception as ex1:
    print(ex1)
# Out:
# division by zero

# %%
## try, except, else block 

try:
    num=int(input("enter a number"))
    result=10/num
except ValueError:
    print("this is not valid number")
except Exception as ex1:
    print(ex1)
else: # after the execution is happened successfully then else will run, this will not run in case of Exception
    print(result)
finally: 
    print("the code has run ")
# Out:
# division by zero
# the code has run
